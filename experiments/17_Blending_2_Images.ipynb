# %%
import cv2
import matplotlib.pyplot as plt

# Load images
img1 = cv2.imread(r"C:\Users\Abhishek\OneDrive\Pictures\sunset.jpg")
img2 = cv2.imread(r"C:\Users\Abhishek\OneDrive\Pictures\mountain.jpg")

# Convert to RGB
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# Resize second image
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Blend
blended = cv2.addWeighted(img1, 0.5, img2, 0.5, 0)

# Show all images
plt.figure(figsize=(10,4))

plt.subplot(1,3,1)
plt.imshow(img1)
plt.title("Original Image 1")

plt.subplot(1,3,2)
plt.imshow(img2)
plt.title("Original Image 2")

plt.subplot(1,3,3)
plt.imshow(blended)
plt.title("Blended Image")

plt.show()
